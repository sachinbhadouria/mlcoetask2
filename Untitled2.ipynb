# %% [markdown]
# <a href="https://colab.research.google.com/github/sachinbhadouria/mlcoetask2/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#IMPORTING LIBRARIES
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from numpy import math
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn .metrics import mean_squared_error

# %%
df= pd.read_csv("/content/50_Startups.csv")
len(df)
# Out:
# 50

# %%
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# 12   93863.75       127320.38        249839.44     Florida  141585.52
# 13   91992.39       135495.07        252664.93  California  134307.35
# 14  119943.24       156547.42        256512.92     Florida  132602.65
# 15  114523.61       122616.84        261776.23    New York  129917.04
# 16   78013.11       121597.55        264346.06  California  126992.93
# 17   94657.16       145077.58        282574.31    New York  125370.37
# 18   91749.16       114175.79        294919.57     Florida  124266.90
# 19   86419.70       153514.11             0.00    New York  122776.86
# 20   76253.86       113867.30        298664.47  California  118474.03
# 21   78389.47             NaN        299737.29    New York  111313.02
# 22   73994.56             NaN        303319.26     Florida  110352.25
# 23   67532.53             NaN        304768.73     Florida  108733.99
# 24   77044.01             NaN        140574.81    New York  108552.04
# 25   64664.71             NaN        137962.62  California  107404.34
# 26   75328.87       144135.98        134050.07     Florida  105733.54
# 27   72107.60       127864.55        353183.81    New York  105008.31
# 28   66051.52             NaN        118148.20     Florida  103282.38
# 29   65605.48             NaN        107138.38    New York  101004.64
# 30   61994.48             NaN         91131.24     Florida   99937.59
# 31        NaN             NaN         88218.23    New York   97483.56
# 32        NaN             NaN         46085.25  California   97427.84
# 33        NaN             NaN        214634.81     Florida   96778.92
# 34        NaN       157693.92        210797.67  California   96712.80
# 35        NaN        85047.44        205517.64    New York   96479.51
# 36        NaN       127056.21        201126.82     Florida   90708.19
# 37        NaN             NaN        197029.42  California   89949.14
# 38        NaN             NaN        185265.10    New York   81229.06
# 39        NaN             NaN        174999.30  California   81005.76
# 40        NaN             NaN        172795.67  California   78239.91
# 41        NaN             NaN        164470.71     Florida   77798.83
# 42   23640.93             NaN        148001.11  California   71498.49
# 43        NaN             NaN         35534.17    New York   69758.98
# 44   22177.74       154806.14         28334.72  California   65200.33
# 45    1000.23       124153.04          1903.93    New York   64926.08
# 46    1315.46       115816.21        297114.46     Florida   49490.75
# 47       0.00       135426.92             0.00  California   42559.73
# 48     542.05        51743.15             0.00    New York   35673.41
# 49       0.00       116983.80         45173.06  California   14681.40

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
df.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'State', 'Profit'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        38 non-null     float64
#  1   Administration   32 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
df.isnull().sum()
# Out:
# R&D Spend          12
# Administration     18
# Marketing Spend     0
# State               0
# Profit              0
# dtype: int64

# %%
df["R&D Spend"].mean()
# Out:
# 84471.75552631578

# %%
df["Administration"].mean()
# Out:
# 124460.95125

# %%
df["Administration"].median()
# Out:
# 125604.625

# %%
df["R&D Spend"].median()
# Out:
# 82404.58499999999

# %%
updated_df = df
updated_df["R&D Spend"]=updated_df["R&D Spend"].fillna(df["R&D Spend"].median())

# %%
updated_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   32 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
updated_df = df
updated_df["Administration"]=updated_df["Administration"].fillna(df["Administration"].median())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
df.isnull().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
df.dtypes
# Out:
# R&D Spend          float64
# Administration     float64
# Marketing Spend    float64
# State               object
# Profit             float64
# dtype: object

# %%
sns.boxplot(x = 'Profit', data = df)
# Out:
# <Axes: xlabel='Profit'>

# %%
sns.boxplot(x = 'Administration', data = df)
# Out:
# <Axes: xlabel='Administration'>

# %%
sns.kdeplot(x = 'Profit', data = df)
# Out:
# <Axes: xlabel='Profit', ylabel='Density'>

# %%
sns.kdeplot(x = 'R&D Spend', data = df)
# Out:
# <Axes: xlabel='R&D Spend', ylabel='Density'>

# %%
sns.kdeplot(x = 'Administration', data = df)
# Out:
# <Axes: xlabel='Administration', ylabel='Density'>

# %%
corr = df.corr()
# Out:
# <ipython-input-57-45893e33df67>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()

# %%
sns.heatmap(corr, annot = True)
# Out:
# <Axes: >

# %%
fig, axes = plt.subplots(1,4, figsize = (18, 5))

sns.histplot(x = 'R&D Spend', data = df,  ax = axes[0], kde = True)
sns.histplot(x = 'Administration', data = df,  ax = axes[1], kde = True)
sns.histplot(x = 'Marketing Spend', data = df,  ax = axes[2], kde = True)
sns.histplot(x = 'Profit', data = df,  ax = axes[3], kde = True)
# Out:
# <Axes: xlabel='Profit', ylabel='Count'>

# %%
sns.pairplot(df)

# %%
df.shape
# Out:
# (50, 5)

# %%
plt.scatter(df["Marketing Spend"],df["Profit"])
plt.title("scattter plot of profit with Marketing spend")
plt.xlabel("Marketing spend")
plt.ylabel("Profit")
plt.show()

# %%
plt.scatter(df["R&D Spend"],df["Profit"])
plt.title("scattter plot of profit with R&D Spend spend")
plt.xlabel("R&D Spend")
plt.ylabel("Profit")
plt.show()

# %%
plt.scatter(df["Administration"],df["Profit"])
plt.title("scattter plot of profit with administartion")
plt.xlabel("Administration")
plt.ylabel("Profit")
plt.show()

# %%
#create a dummy variable for the catorgarical variable store
ax = df.groupby(["State"])["Profit"].mean().plot.bar(
    figsize = (10,5),
    fontsize = 14
)

#set the title
ax.set_title("average profit of different state where startup operate", fontsize=20)

#set x and y labels
ax.set_xlabel("State",fontsize = 15)
ax.set_ylabel("Profit",fontsize = 15)
# Out:
# Text(0, 0.5, 'Profit')

# %%
df.State.value_counts()
# Out:
# New York      17
# California    17
# Florida       16
# Name: State, dtype: int64

# %%
#creating dummy variable for the catogeorical var
df=pd.get_dummies(df)
df
# Out:
#      R&D Spend  Administration  Marketing Spend     Profit  State_California  \
# 0   165349.200      136897.800        471784.10  192261.83                 0
# 1   162597.700      151377.590        443898.53  191792.06                 1
# 2   153441.510      101145.550        407934.54  191050.39                 0
# 3   144372.410      118671.850        383199.62  182901.99                 0
# 4   142107.340       91391.770        366168.42  166187.94                 0
# 5   131876.900       99814.710        362861.36  156991.12                 0
# 6   134615.460      147198.870        127716.82  156122.51                 1
# 7   130298.130      145530.060        323876.68  155752.60                 0
# 8   120542.520      148718.950        311613.29  152211.77                 0
# 9   123334.880      108679.170        304981.62  149759.96                 1
# 10  101913.080      110594.110        229160.95  146121.95                 0
# 11  100671.960       91790.610        249744.55  144259.40                 1
# 12   93863.750      127320.380        249839.44  141585.52                 0
# 13   91992.390      135495.070        252664.93  134307.35                 1
# 14  119943.240      156547.420        256512.92  132602.65                 0
# 15  114523.610      122616.840        261776.23  129917.04                 0
# 16   78013.110      121597.550        264346.06  126992.93                 1
# 17   94657.160      145077.580        282574.31  125370.37                 0
# 18   91749.160      114175.790        294919.57  124266.90                 0
# 19   86419.700      153514.110             0.00  122776.86                 0
# 20   76253.860      113867.300        298664.47  118474.03                 1
# 21   78389.470      125604.625        299737.29  111313.02                 0
# 22   73994.560      125604.625        303319.26  110352.25                 0
# 23   67532.530      125604.625        304768.73  108733.99                 0
# 24   77044.010      125604.625        140574.81  108552.04                 0
# 25   64664.710      125604.625        137962.62  107404.34                 1
# 26   75328.870      144135.980        134050.07  105733.54                 0
# 27   72107.600      127864.550        353183.81  105008.31                 0
# 28   66051.520      125604.625        118148.20  103282.38                 0
# 29   65605.480      125604.625        107138.38  101004.64                 0
# 30   61994.480      125604.625         91131.24   99937.59                 0
# 31   82404.585      125604.625         88218.23   97483.56                 0
# 32   82404.585      125604.625         46085.25   97427.84                 1
# 33   82404.585      125604.625        214634.81   96778.92                 0
# 34   82404.585      157693.920        210797.67   96712.80                 1
# 35   82404.585       85047.440        205517.64   96479.51                 0
# 36   82404.585      127056.210        201126.82   90708.19                 0
# 37   82404.585      125604.625        197029.42   89949.14                 1
# 38   82404.585      125604.625        185265.10   81229.06                 0
# 39   82404.585      125604.625        174999.30   81005.76                 1
# 40   82404.585      125604.625        172795.67   78239.91                 1
# 41   82404.585      125604.625        164470.71   77798.83                 0
# 42   23640.930      125604.625        148001.11   71498.49                 1
# 43   82404.585      125604.625         35534.17   69758.98                 0
# 44   22177.740      154806.140         28334.72   65200.33                 1
# 45    1000.230      124153.040          1903.93   64926.08                 0
# 46    1315.460      115816.210        297114.46   49490.75                 0
# 47       0.000      135426.920             0.00   42559.73                 1
# 48     542.050       51743.150             0.00   35673.41                 0
# 49       0.000      116983.800         45173.06   14681.40                 1
#
#     State_Florida  State_New York
# 0               0               1
# 1               0               0
# 2               1               0
# 3               0               1
# 4               1               0
# 5               0               1
# 6               0               0
# 7               1               0
# 8               0               1
# 9               0               0
# 10              1               0
# 11              0               0
# 12              1               0
# 13              0               0
# 14              1               0
# 15              0               1
# 16              0               0
# 17              0               1
# 18              1               0
# 19              0               1
# 20              0               0
# 21              0               1
# 22              1               0
# 23              1               0
# 24              0               1
# 25              0               0
# 26              1               0
# 27              0               1
# 28              1               0
# 29              0               1
# 30              1               0
# 31              0               1
# 32              0               0
# 33              1               0
# 34              0               0
# 35              0               1
# 36              1               0
# 37              0               0
# 38              0               1
# 39              0               0
# 40              0               0
# 41              1               0
# 42              0               0
# 43              0               1
# 44              0               0
# 45              0               1
# 46              1               0
# 47              0               0
# 48              0               1
# 49              0               0

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend     Profit  State_California  \
# 0  165349.20       136897.80        471784.10  192261.83                 0
# 1  162597.70       151377.59        443898.53  191792.06                 1
# 2  153441.51       101145.55        407934.54  191050.39                 0
# 3  144372.41       118671.85        383199.62  182901.99                 0
# 4  142107.34        91391.77        366168.42  166187.94                 0
#
#    State_Florida  State_New York
# 0              0               1
# 1              0               0
# 2              1               0
# 3              0               1
# 4              1               0

# %%
depandent_variable = "Profit"
#creating a list of indepandent variable
indep = df.columns.tolist()
indep.remove(depandent_variable)
indep
# Out:
# ['R&D Spend',
#  'Administration',
#  'Marketing Spend',
#  'State_California',
#  'State_Florida',
#  'State_New York']

# %%
#creating depandent variable dataset
x = df[indep].values
#Creating indepandent variable dataset

y = df[depandent_variable].values

# %%
#spilliting the dataset into training set and testset
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
#transformming data
scaler=MinMaxScaler()
x_train= scaler.fit_transform(x_train)
xtest= scaler.transform(x_test)

# %%
x_train[0:10]
# Out:
# array([[0.498367  , 0.69713014, 0.45494286, 0.        , 1.        ,
#         0.        ],
#        [0.498367  , 0.3143374 , 0.43561799, 0.        , 0.        ,
#         1.        ],
#        [0.45557444, 0.87203547, 0.28413435, 0.        , 1.        ,
#         0.        ],
#        [0.498367  , 1.        , 0.44680961, 1.        , 0.        ,
#         0.        ],
#        [0.55488118, 0.58926084, 0.62511553, 0.        , 1.        ,
#         0.        ],
#        [0.7880179 , 0.88519328, 0.68649342, 0.        , 1.        ,
#         0.        ],
#        [0.72539353, 0.98917894, 0.54370828, 0.        , 1.        ,
#         0.        ],
#        [0.0060492 , 0.68342958, 0.0040356 , 0.        , 0.        ,
#         1.        ],
#        [0.00327821, 0.        , 0.        , 0.        , 0.        ,
#         1.        ],
#        [0.39676926, 0.69713014, 0.22709197, 0.        , 0.        ,
#         1.        ]])

# %%
pd
# Out:
# <module 'pandas' from '/usr/local/lib/python3.10/dist-packages/pandas/__init__.py'>
